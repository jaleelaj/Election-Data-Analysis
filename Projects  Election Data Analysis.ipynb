# %% [markdown]
# # importing

# %%
import numpy as np 
import pandas as pd

# %%
data=pd.read_csv('indian-state-level-election.csv')

# %%
data.head()
# Out:
#           st_name    year  ac_no    ac_name ac_type  \
# 0  Andhra Pradesh  1978.0      1  Ichapuram     GEN
# 1  Andhra Pradesh  1978.0      1  Ichapuram     GEN
# 2  Andhra Pradesh  1978.0      1  Ichapuram     GEN
# 3  Andhra Pradesh  1978.0      1  Ichapuram     GEN
# 4  Andhra Pradesh  1978.0      1  Ichapuram     GEN
#
#                    cand_name cand_sex                     partyname  \
# 0           Manabala Ramarao        M                   Independent
# 1                Appadu Sahu        M                   Independent
# 2           Uppada Rangababu        M      Indian National Congress
# 3       Kalla Balarama Swamy        M  Indian National Congress (I)
# 4  Bendalam Venkatesam Sarma        M                  Janata Party
#
#   partyabbre  totvotpoll  electors
# 0        IND       813.0     83247
# 1        IND      1743.0     83247
# 2        INC      4427.0     83247
# 3     INC(I)     19805.0     83247
# 4        JNP     34251.0     83247

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 327294 entries, 0 to 327293
# Data columns (total 11 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   st_name     327294 non-null  object
#  1   year        327294 non-null  float64
#  2   ac_no       327294 non-null  int64
#  3   ac_name     311211 non-null  object
#  4   ac_type     327294 non-null  object
#  5   cand_name   327294 non-null  object
#  6   cand_sex    321992 non-null  object
#  7   partyname   327294 non-null  object
#  8   partyabbre  324588 non-null  object
#  9   totvotpoll  327287 non-null  float64
#  10  electors    327294 non-null  int64
# dtypes: float64(2), int64(2), object(7)
# memory usage: 27.5+ MB

# %%
data.isnull().sum()
# Out:
# st_name           0
# year              0
# ac_no             0
# ac_name       16083
# ac_type           0
# cand_name         0
# cand_sex       5302
# partyname         0
# partyabbre     2706
# totvotpoll        7
# electors          0
# dtype: int64

# %%
data.st_name.unique()
# Out:
# array(['Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'Bihar',
#        'Chhattisgarh', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh',
#        'Jammu & Kashmir', 'Jharkhand', 'Karnataka', 'Kerala',
#        'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram',
#        'Nagaland', 'National Capital Territory Of Delhi', 'Odisha',
#        'Puducherry', 'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu',
#        'Tripura', 'Uttar Pradesh', 'Uttarakhand', 'West Bengal'],
#       dtype=object)

# %%
data[data['st_name']=='Gujarat']['cand_sex'].value_counts()
# Out:
# M    11120
# F      484
# Name: cand_sex, dtype: int64

# %%
data['cand_sex']=data['cand_sex'].fillna('M')

# %%
data['cand_sex'].isnull().sum()
# Out:
# 0

# %%
data.isnull().sum()
# Out:
# st_name           0
# year              0
# ac_no             0
# ac_name       16083
# ac_type           0
# cand_name         0
# cand_sex          0
# partyname         0
# partyabbre     2706
# totvotpoll        7
# electors          0
# dtype: int64

# %%
ls=['totvotpoll','electors']
data[ls]
# Out:
#         totvotpoll  electors
# 0            813.0     83247
# 1           1743.0     83247
# 2           4427.0     83247
# 3          19805.0     83247
# 4          34251.0     83247
# ...            ...       ...
# 327289      2471.0    189320
# 327290      3074.0    189320
# 327291      4961.0    189320
# 327292     73414.0    189320
# 327293     77817.0    189320
#
# [327294 rows x 2 columns]

# %%
round(data.totvotpoll.mean(), 0)
# Out:
# 9300.0

# %%
data['totvotpoll'] = data['totvotpoll'].fillna(round(data['totvotpoll'].mean()))

# %%
data.totvotpoll.isnull().sum()
# Out:
# 0

# %%
data.head(10)
# Out:
#           st_name    year  ac_no    ac_name ac_type  \
# 0  Andhra Pradesh  1978.0      1  Ichapuram     GEN
# 1  Andhra Pradesh  1978.0      1  Ichapuram     GEN
# 2  Andhra Pradesh  1978.0      1  Ichapuram     GEN
# 3  Andhra Pradesh  1978.0      1  Ichapuram     GEN
# 4  Andhra Pradesh  1978.0      1  Ichapuram     GEN
# 5  Andhra Pradesh  1978.0      2    Sompeta     GEN
# 6  Andhra Pradesh  1978.0      2    Sompeta     GEN
# 7  Andhra Pradesh  1978.0      2    Sompeta     GEN
# 8  Andhra Pradesh  1978.0      3    Tekkali     GEN
# 9  Andhra Pradesh  1978.0      3    Tekkali     GEN
#
#                    cand_name cand_sex                     partyname  \
# 0           Manabala Ramarao        M                   Independent
# 1                Appadu Sahu        M                   Independent
# 2           Uppada Rangababu        M      Indian National Congress
# 3       Kalla Balarama Swamy        M  Indian National Congress (I)
# 4  Bendalam Venkatesam Sarma        M                  Janata Party
# 5        Ganni Padmanabharao        M      Indian National Congress
# 6            Tulasidas Majji        M  Indian National Congress (I)
# 7           Gouthu Latchanna        M                  Janata Party
# 8              Hussana Begam        F  Indian National Congress (I)
# 9   Satharu Lakanadham Naidu        M      Indian National Congress
#
#   partyabbre  totvotpoll  electors
# 0        IND       813.0     83247
# 1        IND      1743.0     83247
# 2        INC      4427.0     83247
# 3     INC(I)     19805.0     83247
# 4        JNP     34251.0     83247
# 5        INC      2694.0     91272
# 6     INC(I)     28251.0     91272
# 7        JNP     42251.0     91272
# 8     INC(I)      7998.0     90959
# 9        INC     22502.0     90959

# %%
data[data['st_name']=='Andhra Pradesh']['year'].unique()
# Out:
# array([1978., 1983., 1985., 1989., 1994., 1999., 2004., 2009., 2014.])

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
x=data[data['st_name']=='Andhra Pradesh']['year'].unique()
y=data[data['st_name']=='Andhra Pradesh'].groupby('year')['electors'].sum()
plt.scatter(x,y,c='red')
plt.plot(x,y)
plt.title('Andhra Pradesh')
plt.xlabel("Year")
plt.ylabel("Total Electors")
plt.show()

# %%
def total_electors(state):
    x=data[data['st_name']==state]['year'].unique()
    y=data[data['st_name']==state].groupby('year')['electors'].sum()
    plt.scatter(x,y,c='red')
    plt.plot(x,y)
    plt.title(state)
    plt.xlabel("Year")
    plt.ylabel("Total Electors")
    plt.show()

# %%
total_electors('Bihar')

# %%
total_electors('Nagaland')

# %%
total_electors('Rajasthan')

# %%
data.tail(10)
# Out:
#             st_name    year  ac_no  ac_name ac_type                cand_name  \
# 327284  West Bengal  2011.0    293  Nalhati     GEN            Bikash Mondal
# 327285  West Bengal  2011.0    293  Nalhati     GEN              Anil Singha
# 327286  West Bengal  2011.0    293  Nalhati     GEN         Dipak Chatterjee
# 327287  West Bengal  2011.0    293  Nalhati     GEN        Abhijit Mukherjee
# 327288  West Bengal  2011.0    294  Murarai     GEN    Mir Mukid(Hazi Rekib)
# 327289  West Bengal  2011.0    294  Murarai     GEN                Ajrail Md
# 327290  West Bengal  2011.0    294  Murarai     GEN           Shiblal Sardar
# 327291  West Bengal  2011.0    294  Murarai     GEN  Sudhiranjan Das Goswami
# 327292  West Bengal  2011.0    294  Murarai     GEN           Elahi Kamre Dr
# 327293  West Bengal  2011.0    294  Murarai     GEN      Nure Alam Chowdhury
#
#        cand_sex partyname partyabbre  totvotpoll  electors
# 327284        M       BSP        BSP      2717.0    176438
# 327285        M       BJP        BJP     10656.0    176438
# 327286        M      AIFB       AIFB     60887.0    176438
# 327287        M       INC        INC     76047.0    176438
# 327288        M        JP         JP      1228.0    189320
# 327289        M       IND        IND      2471.0    189320
# 327290        M       BSP        BSP      3074.0    189320
# 327291        M       BJP        BJP      4961.0    189320
# 327292        M       CPM        CPM     73414.0    189320
# 327293        M      AITC       AITC     77817.0    189320

# %%
data.ac_type.unique()
# Out:
# array(['GEN', 'ST', 'SC', 'BL', 'SANGH'], dtype=object)

# %%
def seat_type(s1,s2,s3,s4,s5):
    v1=data[data['st_name']==s1]['ac_type'].value_counts()
    v2=data[data['st_name']==s2]['ac_type'].value_counts()
    v3=data[data['st_name']==s3]['ac_type'].value_counts()
    v4=data[data['st_name']==s4]['ac_type'].value_counts()
    v5=data[data['st_name']==s5]['ac_type'].value_counts()
    df=pd.DataFrame([v1,v2,v3,v4,v5])
    df.index=[s1,s2,s3,s4,s5]
    df.plot(kind='bar',stacked=True,figsize=(10,5))

# %%
seat_type('Jammu & Kashmir','Punjab','Himachal Pradesh','Haryana','National Capital Territory Of Delhi')

# %%
seat_type('Uttar Pradesh','Bihar','Rajasthan','Madhya Pradesh','Jharkhand')

# %%
seat_type('Gujarat','Maharashtra','Chhattisgarh','Odisha','West Bengal')

# %%
seat_type('Goa','Karnataka','Tamil Nadu','Kerala','Andhra Pradesh')

# %%
seat_type('Puducherry','Uttarakhand','Sikkim','Assam','Tripura')

# %%
party=data[data['st_name']=='Uttar Pradesh']['partyabbre'].value_counts().head().keys()
Data=data[data['st_name']=='Uttar Pradesh']['partyabbre'].value_counts().head()
fig = plt.figure(figsize=(10, 7))
plt.pie(Data, labels=party)
plt.title('Uttar Pradesh')
plt.show()

# %%
def state_wise(state):
    party=data[data['st_name']==state]['partyabbre'].value_counts().head().keys()
    Data=data[data['st_name']==state]['partyabbre'].value_counts().head()
    fig = plt.figure(figsize=(10, 7))
    plt.pie(Data, labels=party)
    plt.title(state)
    plt.show()

# %%
state_wise('Jharkhand')

# %%
state_wise('Kerala')

# %%
state_wise('Tripura')

# %%
data.head()
# Out:
#           st_name    year  ac_no    ac_name ac_type  \
# 0  Andhra Pradesh  1978.0      1  Ichapuram     GEN
# 1  Andhra Pradesh  1978.0      1  Ichapuram     GEN
# 2  Andhra Pradesh  1978.0      1  Ichapuram     GEN
# 3  Andhra Pradesh  1978.0      1  Ichapuram     GEN
# 4  Andhra Pradesh  1978.0      1  Ichapuram     GEN
#
#                    cand_name cand_sex                     partyname  \
# 0           Manabala Ramarao        M                   Independent
# 1                Appadu Sahu        M                   Independent
# 2           Uppada Rangababu        M      Indian National Congress
# 3       Kalla Balarama Swamy        M  Indian National Congress (I)
# 4  Bendalam Venkatesam Sarma        M                  Janata Party
#
#   partyabbre  totvotpoll  electors
# 0        IND       813.0     83247
# 1        IND      1743.0     83247
# 2        INC      4427.0     83247
# 3     INC(I)     19805.0     83247
# 4        JNP     34251.0     83247

# %%
def total_voters(state):
    x=data[data['st_name']==state]['year'].unique()
    y=data[data['st_name']==state].groupby('year')['totvotpoll'].sum()
    plt.scatter(x,y,c='maroon')
    plt.plot(x,y)
    plt.title(state)
    plt.xlabel("Year")
    plt.ylabel("Total Voters")
    plt.show()

# %%
total_voters('Maharashtra')

# %%
total_voters('Odisha')

# %%
data[data['st_name']=='Uttar Pradesh'].groupby('ac_name')['totvotpoll'].sum()[161:180]
# Out:
# ac_name
# Chiraigaon     1007188.0
# Chitrakoot      182425.0
# Chunar         1262563.0
# Colonelganj     972294.0
# Dadraul        1094456.0
# Dadri          1339404.0
# Dalmau          971042.0
# Dariyabad      1098025.0
# Dataganj       1040460.0
# Dayalbagh       918976.0
# Debai          1036555.0
# Dehra Dun       557100.0
# Deoband        1186363.0
# Deoprayag       405537.0
# Deoria         1116392.0
# Derapur         954486.0
# Dhampur        1204546.0
# Dhanapur        904566.0
# Dhanaura        195722.0
# Name: totvotpoll, dtype: float64

# %%
data[data['st_name']=='Uttar Pradesh']['ac_name'].sort_values().unique()[161:180]
# Out:
# array(['Chiraigaon', 'Chitrakoot', 'Chunar', 'Colonelganj', 'Dadraul',
#        'Dadri', 'Dalmau', 'Dariyabad', 'Dataganj', 'Dayalbagh', 'Debai',
#        'Dehra Dun', 'Deoband', 'Deoprayag', 'Deoria', 'Derapur',
#        'Dhampur', 'Dhanapur', 'Dhanaura '], dtype=object)

# %%
ac=data[data['st_name']=='Uttar Pradesh']['ac_name'].sort_values().unique()[:20]
votes=data[data['st_name']=='Uttar Pradesh'].groupby('ac_name')['totvotpoll'].sum()[:20]
fig = plt.figure(figsize=(10, 7))
plt.pie(votes, labels=ac)
plt.title('Uttar Pradesh')
plt.show()

# %%
def seat_wise(state,i,j):
    ac=data[data['st_name']==state]['ac_name'].sort_values().unique()[i:j]
    votes=data[data['st_name']==state].groupby('ac_name')['totvotpoll'].sum()[i:j]
    fig = plt.figure(figsize=(10, 7))
    plt.pie(votes, labels=ac)
    plt.title(state)
    plt.show()
seat_wise('Jharkhand',21,40)

# %%
seat_wise('Himachal Pradesh',21,40)

# %%
seat_wise('Gujarat',21,40)

# %%
seat_wise('Karnataka',21,40)

# %%
seat_wise('Meghalaya',21,40)

# %%
data.head()
# Out:
#           st_name    year  ac_no    ac_name ac_type  \
# 0  Andhra Pradesh  1978.0      1  Ichapuram     GEN
# 1  Andhra Pradesh  1978.0      1  Ichapuram     GEN
# 2  Andhra Pradesh  1978.0      1  Ichapuram     GEN
# 3  Andhra Pradesh  1978.0      1  Ichapuram     GEN
# 4  Andhra Pradesh  1978.0      1  Ichapuram     GEN
#
#                    cand_name cand_sex                     partyname  \
# 0           Manabala Ramarao        M                   Independent
# 1                Appadu Sahu        M                   Independent
# 2           Uppada Rangababu        M      Indian National Congress
# 3       Kalla Balarama Swamy        M  Indian National Congress (I)
# 4  Bendalam Venkatesam Sarma        M                  Janata Party
#
#   partyabbre  totvotpoll  electors
# 0        IND       813.0     83247
# 1        IND      1743.0     83247
# 2        INC      4427.0     83247
# 3     INC(I)     19805.0     83247
# 4        JNP     34251.0     83247
